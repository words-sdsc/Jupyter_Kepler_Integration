# %% [markdown]
# <br><br><h1 style="font-size:4em;color:#2467C0">Kepler + Jupyter Notebook</h1><br><br><br>

# %%
import KeplerMagicFunction

# %% [markdown]
# <br><br><h1 style="font-size:2em;color:#2467C0">What is Kepler Magic Function ?</h1><br><br><br>

# %% [markdown]
# <div style="color:black;font-size:1.25em">
# <br>We have designed a Line Magic Function to run Kepler from Jupyter Notebook with a command line style syntax.</br>
# </div>

# %% [markdown]
# <br><br><h1 style="font-size:2em;color:#2467C0">Step 1: Declare location of Kepler on your machine</h1><br><br><br>

# %%
# %KpConf /Users/spurawat/Kepler_Repository/bioKepler-2017/kepler.modules/kepler.sh

# %% [markdown]
# <br><br><h1 style="font-size:2em;color:#2467C0">Step 2: Declare location of the workflow you want to execute</h1><br><br><br>

# %%
# %WpConf /Users/spurawat/kepler-ipython/IPython-Kepler-Magic-Function/chisquare-plot.xml

# %% [markdown]
# <br><br><h1 style="font-size:2em;color:#2467C0">Step 3: Start Kepler from IPython using Kepler Magic Function</h1><br><br><br>

# %%
# %Kepler -iterations 200

# %% [markdown]
# <br><br><h1 style="font-size:2em;color:#2467C0">Step 4: Process the Output</h1><br><br><br>

# %%
# %readoutput chisquare-plot.SequencePlotter.png

# %% [markdown]
# <br><br><br><h1> Useful Resources </h1>
# <h1><a href="https://kepler-project.org/users/downloads"> Download Kepler installers </a></h1>
# <h1><a href="https://kepler-project.org/users/documentation"> Kepler User Documentation </a></h1>
# <h1><a href="http://www.biokepler.org/userguide"> bioKepler User Guide </a></h1>
# <h1><a href="https://biobigdata.ucsd.edu/"> Biomedical Big Data Training Collaborative </a></h1>
# <br><br>

# %% [markdown]
# <br><br><h1 style="font-size:4em;text-align: center;color:#2467C0">Thank you</h1><br><br><br>
